# %% [markdown]
# > # Naive Bayes

# %% [markdown]
# Since we know that how Naiave bayes alog work
#
# p(Ck|X) = arg max p(Ck) product(p(xi|Ck))
#
# if we have 3 columns (toss, venue, outlook) and result(Win, Loss)
#
# then;
#
# p(Win|(toss_win,london,sunny)) = p(toss_win|Win) p(london|Win) p(sunny|Win) p(Win)
#
# >## You know it is all done in prediction part, but what our model does in training part???
# ___
# >### Trainig
#
# it create lookup table, where it store all possible probab in dictionary
#
# >### Testing
# it just calc probab

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('play_tennis.csv')

# %%
data.head()
# Out:
#   day   outlook  temp humidity    wind play
# 0  D1     Sunny   Hot     High    Weak   No
# 1  D2     Sunny   Hot     High  Strong   No
# 2  D3  Overcast   Hot     High    Weak  Yes
# 3  D4      Rain  Mild     High    Weak  Yes
# 4  D5      Rain  Cool   Normal    Weak  Yes

# %% [markdown]
# Creating our own lookup table

# %%
# p(No) and p(Yes) in play col
p_yes_no = []
total = data['play'].value_counts().values.sum()
for i in data['play'].value_counts().values:
    p_yes_no.append(i/total)
    pass

p_yes_no
# Out:
# [np.float64(0.6428571428571429), np.float64(0.35714285714285715)]

# %%
pd.crosstab(data['outlook'], data['play'])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
# p(overcast|no)
pOvercastNo = 0
# p(rain|no)
pRainNo = 2/5
# p(sunny|no)
pSunnyNo = 3/5

# p(overcast|yes)
pOvercastYes = 4/9
# p(rain|yes)
pRainYes = 3/9
# p(sunny|yes)
pSunnyYes = 2/9

# %%
pd.crosstab(data['temp'], data['play'])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
# p(cool|no)
pCoolNo = 1/5
# p(hot|no)
pHotNo = 2/5
# p(mild|no)
pMildNo = 2/5

# p(cool|yes)
pCoolYes = 3/9
# p(hot|yes)
pHotYes = 2/9
# p(mild|yes)
pMildYes = 4/9

# %%
pd.crosstab(data['humidity'], data['play'])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
# p(high|no)
pHighNo = 4/5
# p(normal|no)
pNormalNo = 1/5

# p(high|yes)
pHighYes = 3/9
# p(normal|yes)
pNormalYes = 6/9

# %%
pd.crosstab(data['wind'], data['play'])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
# p(strong|no)
pStrongNo = 3/5
# p(weak|no)
pWeakNo = 2/5

# p(strong|yes)
pStrongYes = 3/9
# p(weak|yes)
pWeakYes = 6/9

# %% [markdown]
# Training complete
# ____
# Prediction

# %%
# outlook=sunny, tem=hot, humidity=high, wind=weak
# p(sunny, hot, high, weak | play(yes or no))

pyes = p_yes_no[0] * pSunnyYes * pHotYes * pHighYes * pWeakYes
pno = p_yes_no[1] * pSunnyNo * pHotNo * pHighNo * pWeakNo

# %%
if pyes > pno:
    print("yes")
else:
    print('no')
# Out:
# no

# %%
from sklearn.naive_bayes import CategoricalNB
from sklearn.preprocessing import LabelEncoder

# %%
df = data.drop('day', axis=1)
le = LabelEncoder()
for col in df.columns:
    df[col] = le.fit_transform(df[col])

# %%
data.head()
# Out:
#   day   outlook  temp humidity    wind play
# 0  D1     Sunny   Hot     High    Weak   No
# 1  D2     Sunny   Hot     High  Strong   No
# 2  D3  Overcast   Hot     High    Weak  Yes
# 3  D4      Rain  Mild     High    Weak  Yes
# 4  D5      Rain  Cool   Normal    Weak  Yes

# %%
df.head()
# OUTLOOK
# sunny = 2, overcast = 0, rain=1
# TEMP
# hot = 1, mild=2, cool=0
# HUMIDITY
# high = 0, normal=1
# WIND
# weak=1, strong=0
# Out:
#    outlook  temp  humidity  wind  play
# 0        2     1         0     1     0
# 1        2     1         0     0     0
# 2        0     1         0     1     1
# 3        1     2         0     1     1
# 4        1     0         1     1     1

# %%
nb = CategoricalNB()

nb.fit(df.iloc[:, :-1], df.iloc[:, -1])
# Out:
# CategoricalNB()

# %%
# outlook=sunny, tem=hot, humidity=high, wind=weak
# OUTLOOK
# sunny = 2, overcast = 0, rain=1
# TEMP
# hot = 1, mild=2, cool=0
# HUMIDITY
# high = 0, normal=1
# WIND
# weak=1, strong=0
if nb.predict([[2, 1, 0, 1]]):
    print('yes')
else:
    print('no')
# Out:
# no
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but CategoricalNB was fitted with feature names
#   warnings.warn(
