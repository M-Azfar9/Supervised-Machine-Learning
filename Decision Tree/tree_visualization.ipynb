# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset('iris')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['species'] = le.fit_transform(data['species'])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data.drop('species', axis=1), data['species'], test_size=0.2)

# %%
y_train.shape, x_train.shape
# Out:
# ((120,), (120, 4))

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier(criterion='gini')

# %%
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = dtc.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(pred, y_test)
# Out:
# 0.9523052464228935

# %%
from sklearn.tree import plot_tree
plot_tree(dtc)
# Out:
# [Text(0.4444444444444444, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 120\nvalue = [40, 40, 40]'),
#  Text(0.3333333333333333, 0.75, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]'),
#  Text(0.38888888888888884, 0.8333333333333333, 'True  '),
#  Text(0.5555555555555556, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 80\nvalue = [0, 40, 40]'),
#  Text(0.5, 0.8333333333333333, '  False'),
#  Text(0.4444444444444444, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.198\nsamples = 45\nvalue = [0, 40, 5]'),
#  Text(0.2222222222222222, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.05\nsamples = 39\nvalue = [0, 38, 1]'),
#  Text(0.1111111111111111, 0.25, 'gini = 0.0\nsamples = 38\nvalue = [0, 38, 0]'),
#  Text(0.3333333333333333, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.5555555555555556, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.7777777777777778, 0.25, 'x[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.6666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8888888888888888, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6666666666666666, 0.5833333333333334, 'gini = 0.0\nsamples = 35\nvalue = [0, 0, 35]')]

# %%
from sklearn.datasets import *
dtc = DecisionTreeClassifier(max_depth=2)
iris = load_iris()
data = iris.data
target = iris.target
dtc.fit(data, target)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
plot_tree(dtc)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.30000000000000004, 0.6666666666666667, 'True  '),
#  Text(0.6, 0.5, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5, 0.6666666666666667, '  False'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.043\nsamples = 46\nvalue = [0, 1, 45]')]

# %%
from dtreeviz.trees import dtre


viz = dtreeviz(
    dtc,
    data,
    target,
    target_name='iris',
    feature_names=iris.feature_names,
    class_names=list(iris.target_names),
)
viz
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 from dtreeviz.trees import dtreeviz
#       4 viz = dtreeviz(
#       5     dtc,
#       6     data,
#    (...)
#      10     class_names=list(iris.target_names),
#      11 )
#      12 viz
#
# ImportError: cannot import name 'dtreeviz' from 'dtreeviz.trees' (c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\dtreeviz\trees.py)

# %%
import dtreeviz
print(dtreeviz.__version__)
# Out:
# 2.2.2
